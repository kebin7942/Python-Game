# %% [markdown]
# <a href="https://colab.research.google.com/github/kebin7942/Python-Game/blob/main/6_%ED%8A%B9%EC%A7%95%EC%9E%90%EC%99%80_%EB%A7%A4%EC%B9%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, cv2
import numpy as np
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow
from google.colab import files

def get_image():
    upload = files.upload()
    filename = list(upload.keys())[0]
    return filename

# %%
#진열대 사진
background_path = get_image()
background = cv2.imread(background_path)
cv2_imshow(background)
# Out:
#      <input type="file" id="files-ad276fb0-fbad-47ab-9e01-03a340e3ef41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ad276fb0-fbad-47ab-9e01-03a340e3ef41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#낱개 상품 사진
target_path = get_image()
target = cv2.imread(target_path)
cv2_imshow(target)
# Out:
#      <input type="file" id="files-a00a543c-c123-4fc0-a5fb-fbdba4754687" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a00a543c-c123-4fc0-a5fb-fbdba4754687">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(cv2.imread(background_path))
axes[1].imshow(cv2.imread(target_path))
plt.show()
